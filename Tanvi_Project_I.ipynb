# %% [markdown]
# <a href="https://colab.research.google.com/github/singlatanvi67-netizen/Project1-python.26/blob/main/Tanvi_Project_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
movies_collection={
    "Action": ["War","Pathan","Commando", "Ghajini", "Baaghi","Baaghi2", "Mass", "Fast Five", "Dhoom", "Simmba", "Dhoom2", "Tiger Zinda Hai", "Dabangg", "Dabangg2", "Ek Tha Tiger", "Dhoom3", "Singham","Singham Returns","Fast & Furious", "Avengers:Endgame", "Mission Impossible:Fallout", "Mossion Impossible: Ghost Protocol", "John Wick", "John Wick: Chapter2", "John Wick: Chapter3", "Die Hard", "Extraction", "Gladitor", "Mad Max:Fury Road", " The Dark Knight"], "Comedy": ["Munna Bhai M.B.B.S.", "3Idiots","Dhamaal", "Double Dhamaal", "Golmaal: Fun Unlimited", "Golmaal Returns", "Hera Pheri", "Phir Hera Pheri","Housefull", "Housefull2", "Chup Chup ke", "Lage Raho Munna Bhai","Mr. Beans Holiday", "The Mask", "Central Intelligence", "Home Alone", "Home Alone2", "Rush Hour", "Rush Hour 2", "The Hangover", "The Hangover Part II", "Johnny English", "Johnny English Reborn", "Jumanji: Welcome to the Jungle", "Deadpool", "Bhool Bhulaiyaa", "Bhool Bhulaiyaa2", "Welcome", "Welcome Back", "Welcome to the Jungle"],
    "Drama": ["Anand","Queen","Kal Ho Naa Ho", "Pink", "Piku", "Gully Boy", "Taare Zameen Par", "Bajrangi Bhaijaan", "Zindagi Na Milegi Dobara", "Black", "Kabir Singh", "My Name Is Khan", "Dear Zindagi", "Swades","Fight Club", "The Green Mile", " Life of Pi", "The NOtebook", "A Beutiful Mind", "Good Will Hunting", "The Social Network", " Joker", "The Revenant", "Slumdog Millionaire", "The Fault in Our Stars", " Titanic", "Forrest Gump", "The Shawshank Redemption", "The Pursuit of Happyness", ],
    "Sci-Fi": ["Koi Mil Gaya", "Tenet","Krish", "Krish2", "Dawn of the Planet of the Apes", "Rise of the Planet of the Apes", "Robot", "2.0", "Planet of the Apes", "War of the Worlds", "The Matrix", "The Matrix Reloaded", "Avatar", "Avatar: Thw Way of Water","Gravity", "Arrival", "Edge of Tomorrow", "Terminator", "Terminator 2: Judgement Day", "Jurassic Park", " A Quiet Place", "E.T. the Extra-Terrestrial", "Interstellar", "Inception", "Dune", "Dune:Part two", "The Martian", "Blade Runner", "Blade Runner 2049", "Jurasic Park"],
    "Horror": ["Pari", "Bhoot", "Virana", "Bhool Bhulaiyaa", "Stree", "Raaz", "Raaz 2", "Haunted 3D", " 1920", "Tumbbad", "Annabelle", "The Nun", "Annabelle: Creation", " The Conjuring", "The Conjuring 2", "IT", "The Exrocist", " Insidious", "A Quiet Place", "1920: Evil Returns", "Aval", "Prema Katha Chitram", "Virupaksha", "Eeram", " Muni", " Arundhati", "Kanchana 2", " Bhaagamethie", "Pizza"]
}

def display_genres():
  print("\nAvailable Genres are: ")
  for genre in movies_collection.keys():
    print("-",genre)

def recommended_movies():
  display_genres()
  genre=input("\nSelect a genre: ")
  if genre in movies_collection.keys():
    try:
      num=int(input("How many recommendations do you want? "))
      movies=movies_collection[genre]
      if num > len(movies):
        print(f"Only {len(movies)} movies available.")
        num = len(movies)

      recommendations = random.sample(movies, num)

      print("\n🎬 Recommended Movies:")
      for movie in recommendations:
                print("-", movie)

    except ValueError:
      print("Please enter a valid number.")
  else:
    print("Genre not found.")

def add_movie():
    genre = input("Enter genre: ")
    movie = input("Enter movie name: ")

    if genre in movies_collection:
        movies_collection[genre].append(movie)
    else:
        movies_collection[genre] = [movie]

    print(f"{movie} has been added to {genre} genre.")

def search_movie():
    movie_name = input("Enter movie name to search: ")
    found = False

    for genre, movies in movies_collection.items():
        if movie_name in movies:
            print(f"{movie_name} found in {genre} genre.")
            found = True
            break

    if not found:
        print("Movie not found in collection.")

def main():
    while True:
        print("\n===== Movie Recommendation System =====")
        print("1. Get Movie Recommendations")
        print("2. Add a Movie")
        print("3. Search for a Movie")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            recommended_movies()
        elif choice == "2":
            add_movie()
        elif choice == "3":
            search_movie()
        elif choice == "4":
            print("Thank you for using the Movie Recommendation System!")
            break
        else:
            print("Invalid choice. Please try again.")

# Run the program
main()
# Out:
# ===== Movie Recommendation System =====
# 1. Get Movie Recommendations
# 2. Add a Movie
# 3. Search for a Movie
# 4. Exit
# Enter your choice: 1
#
# Available Genres are:
# - Action
# - Comedy
# - Drama
# - Sci-Fi
# - Horror
#
# Select a genre: Action
# How many recommendations do you want? 2
#
# 🎬 Recommended Movies:
# - Fast Five
# - John Wick: Chapter2
#
# ===== Movie Recommendation System =====
# 1. Get Movie Recommendations
# 2. Add a Movie
# 3. Search for a Movie
# 4. Exit
# Enter your choice: 4
# Thank you for using the Movie Recommendation System!
